# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter  # Importa FuncFormatter

# %%
df_arroz = pd.read_csv("Arroz_data_LISTA.csv")
df_maiz = pd.read_csv("Maiz_data_LISTA.csv")
df_soja = pd.read_csv("Soja_data_LISTA.csv")
df_trigo = pd.read_csv("Trigo_data_LISTA.csv")

# %%
plt.plot(df_arroz['Mes'], df_arroz['Precio'], marker='.', label = "Arroz", color = "brown")
plt.plot(df_maiz['Mes'], df_maiz['Precio'], marker='+', label = "Maiz", color = "yellow")
plt.plot(df_soja['Mes'], df_soja['Precio'], marker='*', label = "Soja", color = "green")
plt.plot(df_trigo['Mes'], df_trigo['Precio'], marker='-', label = "Trigo", color = "Orange")

#activar leyenda
plt.legend()

#etiquetas en los ejes
plt.xlabel("Años") #etiqueta en eje x
plt.ylabel("Precio en dólares por tonelada métrica al cierre del año")#etiqueta en eje y

"""
# Configura el formateador personalizado para el eje x
formatter = FuncFormatter(format_years)
plt.gca().xaxis.set_major_formatter(formatter)

# Establece los límites del eje y para mostrar solo los primeros 3 números
# Configura el formateador personalizado para el eje y sin notación científica
y_formatter = FuncFormatter(format_y_plain)
plt.gca().yaxis.set_major_formatter(y_formatter)


plt.xticks(np.arange(2000, 2020, 1))
#plt.yticks(np.arange(210000, 2020, 3))
"""
#activar cuadricula 
#plt.grid()

plt.legend(loc='upper left', bbox_to_anchor=(0.001, 0.97), handlelength=1, fontsize='small')

#activar marcas menores 
#plt.minorticks_on()
#plt.title("Mercosur4 - Evolución de las exportaciones del Arroz a China") #titulo
plt.grid(True, which='major', axis='both', color='black', linestyle='--', linewidth=0.5, alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\markers.py:335, in MarkerStyle._set_marker(self, marker)
#     334 try:
# --> 335     Path(marker)
#     336     self._marker_function = self._set_vertices
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
# --> 129 vertices = _to_unmasked_float_array(vertices)
#     130 _api.check_shape((None, 2), vertices=vertices)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook.py:1345, in _to_unmasked_float_array(x)
#    1344 else:
# ...

# %%
plt.figure(figsize=(16, 8))

# Crea un gráfico de líneas con tres ejes Y
fig, ax1 = plt.subplots()

# Eje Y 1
ax1.set_xlabel('Años')
ax1.set_ylabel('Precio en dólares por tonelada métrica', color='black')
ax1.plot(df_arroz['Mes'], df_arroz['Precio'], marker='.', markersize=3, label = "Arroz", color = "brown")
ax1.plot(df_maiz['Mes'], df_maiz['Precio'], marker='+', markersize=3, label = "Maiz", color = "black")
ax1.plot(df_soja['Mes'], df_soja['Precio'], marker='*', markersize=3, label = "Soja", color = "green")
ax1.plot(df_trigo['Mes'], df_trigo['Precio'], marker='>', markersize=3, label = "Trigo", color = "Orange")
ax1.tick_params(axis='y', labelcolor='black')

#activar leyenda con cuadro más pequeño
ax1.legend(loc='upper left', bbox_to_anchor=(0.001, 0.97), handlelength=1)

# Especificar el formato de los ticks del eje X para mostrar los años cada 10 años
plt.gca().xaxis.set_major_formatter(ScalarFormatter(useOffset=False))

# Establecer los ticks del eje X manualmente cada 10 años
plt.xticks(np.arange(1994, 2020, 4),fontsize=9)
#plt.yticks(np.arange(210000, 2020, 3))

# Establecer los ticks del eje X manualmente cada 10 años
#plt.yticks(np.arange(1994, 2020, 4),fontsize=9)

#activar cuadricula 
#plt.grid()

# Activar la cuadrícula en el primer eje (ax1)
#ax1.grid(True, axis='y', linestyle='-', color='gray', alpha=0.5)
plt.grid(True, which='major', axis='both', color='blue', linestyle='--', linewidth=0.8, alpha=0.5)
ax1.grid(True, which='major', axis='both', color='black', linestyle='--', linewidth=0.5, alpha=0.35)
#ax2.grid(True, which='major', axis='both', color='red', linestyle='--', linewidth=0.5, alpha=0.3)
#activar marcas menores 

plt.minorticks_on()

#plt.title("Segun la FAO(1961-2019): Área cosechada, rendimiento y producción en China del Maiz")
#plt.savefig(r'C:\Users\Usuario\Desktop\Port Folio\Pandas y Matplotlib\Proyecto I+D UNO\Graf. 2\Correcion\graf. linea maiz.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(16, 8))

# Crea un gráfico de líneas con tres ejes Y
fig, ax1 = plt.subplots()

# Eje Y 1
ax1.set_xlabel('Años')
ax1.set_ylabel('Precio en dólares por tonelada métrica', color='black')
ax1.plot(df_arroz['Mes'], df_arroz['Precio'], marker='.', markersize=3, label = "Arroz", color = "brown")
ax1.plot(df_maiz['Mes'], df_maiz['Precio'], marker='+', markersize=3, label = "Maiz", color = "black")
ax1.plot(df_soja['Mes'], df_soja['Precio'], marker='*', markersize=3, label = "Soja", color = "green")
ax1.plot(df_trigo['Mes'], df_trigo['Precio'], marker='>', markersize=3, label = "Trigo", color = "Orange")
ax1.tick_params(axis='y', labelcolor='black')

#activar leyenda con cuadro más pequeño
ax1.legend(loc='upper left', bbox_to_anchor=(0.001, 0.97), handlelength=1)

# Especificar el formato de los ticks del eje X para mostrar los años cada 10 años
plt.gca().xaxis.set_major_formatter(ScalarFormatter(useOffset=False))

# Establecer los ticks del eje X manualmente cada 10 años
plt.xticks(np.arange(1994, 2020, 4),fontsize=9)
#plt.yticks(np.arange(210000, 2020, 3))

# Establecer los ticks del eje X manualmente cada 10 años
plt.yticks(np.arange(100, 650, 50),fontsize=9)

#activar cuadricula 
#plt.grid()

# Activar la cuadrícula en el primer eje (ax1)
#ax1.grid(True, axis='y', linestyle='-', color='gray', alpha=0.5)
plt.grid(True, which='major', axis='both', color='blue', linestyle='--', linewidth=0.8, alpha=0.5)
ax1.grid(True, which='major', axis='both', color='black', linestyle='--', linewidth=0.5, alpha=0.35)
#ax2.grid(True, which='major', axis='both', color='red', linestyle='--', linewidth=0.5, alpha=0.3)
#activar marcas menores 

plt.minorticks_on()

#plt.title("Segun la FAO(1961-2019): Área cosechada, rendimiento y producción en China del Maiz")
plt.savefig(r'C:\Users\Usuario\Desktop\Port Folio\Pandas y Matplotlib\Proyecto I+D UNO\Graf. 4\Correcion\graf. 4 de linea.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Datos obtenidos de index mundi, cuyos datos a su vez se recopilan y provienen de bloomberg.
#
# link: https://www.indexmundi.com/es/precios-de-mercado

# %% [markdown]
# Consigna :
#
# 4) GRÁFICO: evolución de los precios internacionales (dólares por tonelada) de cada uno de los granos básicos. Periodo 2000-2019. ¿4 gráficos diferentes o todos en el mismo? Dependerá de la escala (precio).
# De acá sería bueno sacar los datos (buscar si se puede descargar la info para replicar los gráficos que ya hace):
# https://fpma.fao.org/giews/fpmat4/#/dashboard/tool/international
# Sino acá pareciera ser más fácil: https://www.indexmundi.com/es/precios-de-mercado/?mercancia=trigo&meses=240 pero comprobar que sean los mismos datos que tiene la FAO.
