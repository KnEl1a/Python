# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df4 = pd.read_excel(r"C:\Users\Usuario\Downloads\Participación de cada uno de los países del Mercosur en las exportaciones del bloque a China 2015-2019.xlsx")

# %%
df = df4[['Unnamed: 0','Arg', 'Bra', 'Par', 'Uru']].round(2)

# %%
df
# Out:
#    Unnamed: 0    Arg    Bra   Par   Uru
# 0        2015  12.49  84.87  0.07  2.58
# 1        2016  10.96  86.84  0.05  2.15
# 2        2017   8.13  89.02  0.05  2.79
# 3        2018   6.06  91.75  0.04  2.15
# 4        2019   9.45  87.88  0.01  2.65

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter  # Importa FuncFormatter

# Definir una función para formatear los valores del eje x (en este caso, para eliminar los puntos flotantes)
def format_years(x, pos):
    return int(x)

def format_y_plain(x, pos):
    return f'{x/1000000000:.0f}'  # Mostrar el número completo sin notación científica

# Crea el gráfico de barras
plt.bar(df['Unnamed: 0'], df['Arg'], width=1/5, label = "Argentina")
plt.bar(df['Unnamed: 0'] + 0.2, df['Bra'], width=1/5, label = "Brasil")
plt.bar(df['Unnamed: 0'] + 0.4, df['Par'], width=1/5, label = "Paraguay")
plt.bar(df['Unnamed: 0'] + 0.6, df['Uru'], width=1/5, label = "Uruguay")

#activar leyenda
plt.legend()

#etiquetas en los ejes
plt.xlabel("Años") #etiqueta en eje x
plt.ylabel("Total FOB US$ [Mil Millones]")#etiqueta en eje y

# Configura el formateador personalizado para el eje x
formatter = FuncFormatter(format_years)
plt.gca().xaxis.set_major_formatter(formatter)

# Establece los límites del eje y para mostrar solo los primeros 3 números
# Configura el formateador personalizado para el eje y sin notación científica
y_formatter = FuncFormatter(format_y_plain)
plt.gca().yaxis.set_major_formatter(y_formatter)



plt.xticks(np.arange(2015, 2020, 1))
#plt.yticks(np.arange(210000, 2020, 3))

#activar cuadricula 
#plt.grid()

#activar marcas menores 
plt.minorticks_on()

#plt.title("Segun la FAO(1961-2019): Área cosechada, rendimiento y producción en China del Arroz")
plt.show()

# %%
# DESCARTAMOS EL ANTERIOR

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter  # Importa FuncFormatter

# Modificado
plt.barh(df['Unnamed: 0'], df['Arg'], label="Arg")
plt.barh(df['Unnamed: 0'], df['Bra'], left=df['Arg'], label="bra")
plt.barh(df['Unnamed: 0'], df['Uru'], left=df['Arg'] + df['Bra'], label="urug")
plt.barh(df['Unnamed: 0'], df['Par'], left=df['Arg'] + df['Bra'] + df['Uru'], label="par")

plt.title("Religiosidad en Sudamérica")
plt.xlabel("Porcentaje de la población")
plt.ylabel("Año")

# Establecer los ticks del eje y
plt.yticks(ticks=df['Unnamed: 0'])

# Rotar las etiquetas del eje y para que estén en posición horizontal
plt.gca().invert_yaxis()

#plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)
plt.show()

# %%
# DESCARTAMOS EL ANTERIOR

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter  # Importa FuncFormatter

# Modificado
plt.barh(df['Unnamed: 0'], df['Arg'], label="Arg")
plt.barh(df['Unnamed: 0'], df['Bra'], left=df['Arg'], label="bra")
plt.barh(df['Unnamed: 0'], df['Par'], left=df['Arg'] + df['Bra'], label="par")
plt.barh(df['Unnamed: 0'], df['Uru'], left=df['Arg'] + df['Bra'] + df['Par'], label="Uru")

plt.title("Religiosidad en Sudamérica")
plt.xlabel("Porcentaje de la participacion en las exportaciones a China")
plt.ylabel("Año")

# Establecer los ticks del eje y
plt.yticks(ticks=df['Unnamed: 0'])

# Rotar las etiquetas del eje y para que estén en posición horizontal
plt.gca().invert_yaxis()

#plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter  # Importa FuncFormatter

# Modificado
plt.barh(df['Unnamed: 0'], df['Arg'], label="Arg")
plt.barh(df['Unnamed: 0'], df['Bra'], left=df['Arg'], label="bra")
plt.barh(df['Unnamed: 0'], df['Par'], left=df['Arg'] + df['Bra'], label="par")
plt.barh(df['Unnamed: 0'], df['Uru'], left=df['Arg'] + df['Bra'] + df['Par'], label="Uru")

#plt.title("Religiosidad en Sudamérica")
plt.xlabel("Porcentaje de la participacion en las exportaciones a China")
plt.ylabel("Año")

# Eliminar los números del eje x
plt.xticks([])

# Establecer los ticks del eje y
plt.yticks(ticks=df['Unnamed: 0'])

# Rotar las etiquetas del eje y para que estén en posición horizontal
plt.gca().invert_yaxis()

#plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter  # Importa FuncFormatter

# Modificado
plt.barh(df['Unnamed: 0'], df['Arg'], label="Arg")
plt.barh(df['Unnamed: 0'], df['Bra'], left=df['Arg'], label="bra")
plt.barh(df['Unnamed: 0'], df['Par'], left=df['Arg'] + df['Bra'], label="par")
plt.barh(df['Unnamed: 0'], df['Uru'], left=df['Arg'] + df['Bra'] + df['Par'], label="Uru")

#plt.title("Religiosidad en Sudamérica")
plt.xlabel("Porcentaje de la participacion en las exportaciones a China")
plt.ylabel("Año")

# Eliminar los números del eje x
plt.xticks([])

# Establecer los ticks del eje y
plt.yticks(ticks=df['Unnamed: 0'])

# Rotar las etiquetas del eje y para que estén en posición horizontal
plt.gca().invert_yaxis()

# Agregar los porcentajes en el centro de cada barra
for index, row in df.iterrows():
    total = row['Arg'] + row['Bra'] + row['Par'] + row['Uru']
    plt.text(total / 2, row['Unnamed: 0'], f"{total:.2f}%", ha='center', va='center')

#plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter  # Importa FuncFormatter

# Modificado
plt.barh(df['Unnamed: 0'], df['Arg'], label="Arg")
plt.barh(df['Unnamed: 0'], df['Bra'], left=df['Arg'], label="bra")
plt.barh(df['Unnamed: 0'], df['Par'], left=df['Arg'] + df['Bra'], label="par")
plt.barh(df['Unnamed: 0'], df['Uru'], left=df['Arg'] + df['Bra'] + df['Par'], label="Uru")

#plt.title("Religiosidad en Sudamérica")
plt.xlabel("Porcentaje de la participacion en las exportaciones a China")
plt.ylabel("Año")

# Eliminar los números del eje x
plt.xticks([])

# Establecer los ticks del eje y
plt.yticks(ticks=df['Unnamed: 0'])

# Rotar las etiquetas del eje y para que estén en posición horizontal
plt.gca().invert_yaxis()

# Agregar los porcentajes en el centro de cada barra
for index, row in df.iterrows():
    total = row['Arg'] + row['Bra'] + row['Par'] + row['Uru']
    plt.text(total / 2, row['Unnamed: 0'], f"{total:.2f}%", ha='center', va='center')

#plt.legend()
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# Datos de ejemplo (simulando tu DataFrame)
data = {
    'Unnamed: 0': [2015, 2016, 2017, 2018, 2019],
    'Arg': [12.49, 10.96, 8.13, 6.06, 9.45],
    'Bra': [84.87, 86.84, 89.02, 91.75, 87.88],
    'Par': [0.07, 0.05, 0.05, 0.04, 0.01],
    'Uru': [2.58, 2.15, 2.79, 2.15, 2.65]
}
df = pd.DataFrame(data)

# Bar plot horizontal
plt.barh(df['Unnamed: 0'], df['Arg'], label="Arg")
plt.barh(df['Unnamed: 0'], df['Bra'], left=df['Arg'], label="Bra")
plt.barh(df['Unnamed: 0'], df['Par'], left=df['Arg'] + df['Bra'], label="Par")
plt.barh(df['Unnamed: 0'], df['Uru'], left=df['Arg'] + df['Bra'] + df['Par'], label="Uru")

plt.title("Religiosidad en Sudamérica")
plt.xlabel("Porcentaje de la participación en las exportaciones a China")
plt.ylabel("Año")

# Establecer los ticks del eje y
plt.yticks(ticks=df['Unnamed: 0'])

# Rotar las etiquetas del eje y para que estén en posición horizontal
plt.gca().invert_yaxis()

for index, row in df.iterrows():
    total = row['Arg'] + row['Bra'] + row['Par'] + row['Uru']
    plt.text(row['Arg'] + row['Bra'] / 2, row['Unnamed: 0'], f"{total:.2f}%", ha='center', va='center')
    plt.text(row['Arg'] + row['Bra'] + row['Par'] / 2, row['Unnamed: 0'], f"{total:.2f}%", ha='center', va='center')
    plt.text(row['Arg'] + row['Bra'] + row['Par'] + row['Uru'] / 2, row['Unnamed: 0'], f"{total:.2f}%", ha='center', va='center')

# Leyenda
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

category_names = ['Strongly disagree', 'Disagree',
                  'Neither agree nor disagree', 'Agree', 'Strongly agree']
results = {
    'Question 1': [10, 15, 17, 32, 26],
    'Question 2': [26, 22, 29, 10, 13],
    'Question 3': [35, 37, 7, 2, 19],
    'Question 4': [32, 11, 9, 15, 33],
    'Question 5': [21, 29, 5, 5, 40],
    'Question 6': [8, 19, 5, 30, 38]
}


def survey(results, category_names):
    """
    Parameters
    ----------
    results : dict
        A mapping from question labels to a list of answers per category.
        It is assumed all lists contain the same number of entries and that
        it matches the length of *category_names*.
    category_names : list of str
        The category labels.
    """
    labels = list(results.keys())
    data = np.array(list(results.values()))
    data_cum = data.cumsum(axis=1)
    category_colors = plt.colormaps['RdYlGn'](
        np.linspace(0.15, 0.85, data.shape[1]))

    fig, ax = plt.subplots(figsize=(9.2, 5))
    ax.invert_yaxis()
    ax.xaxis.set_visible(False)
    ax.set_xlim(0, np.sum(data, axis=1).max())

    for i, (colname, color) in enumerate(zip(category_names, category_colors)):
        widths = data[:, i]
        starts = data_cum[:, i] - widths
        rects = ax.barh(labels, widths, left=starts, height=0.5,
                        label=colname, color=color)

        r, g, b, _ = color
        text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
        ax.bar_label(rects, label_type='center', color=text_color)
    ax.legend(ncols=len(category_names), bbox_to_anchor=(0, 1),
              loc='lower left', fontsize='small')

    return fig, ax


survey(results, category_names)
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = ['A', 'B', 'C', 'D']
y = [10, 20, 30, 40]

# Crear el gráfico de barras
plt.barh(x, y)

# Agregar etiquetas a las barras
plt.bar_label(plt.barh(x, y))

plt.show()

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = ['A', 'B', 'C', 'D']
y = [10, 20, 30, 40]

# Crear el gráfico de barras
barras = plt.bar(x, y)

# Agregar etiquetas dentro de las barras
plt.bar_label(barras, label_type='center')

plt.show()
