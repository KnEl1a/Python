# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# con esto leeremos el archivo tuve que hacer algo raro con ISO porque sino no agarraba

# %%
df = pd.read_csv('C:\\Users\\Usuario\\Downloads\\Maiz.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#     TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 0          C        A     20000101     2000        52    2000            50
# 1          C        A     20000101     2000        52    2000            51
# 2          C        A     20000101     2000        52    2000           124
# 3          C        A     20000101     2000        52    2000           144
# 4          C        A     20000101     2000        52    2000           191
# ..       ...      ...          ...      ...       ...     ...           ...
# 139        C        A     20190101     2019        52    2019           826
# 140        C        A     20190101     2019        52    2019           842
# 141        C        A     20190101     2019        52    2019           854
# 142        C        A     20190101     2019        52    2019           860
# 143        C        A     20190101     2019        52    2019           894
#
#     ReporterISO    ReporterDesc FlowCode  ... IsNetWgtEstimated  GrossWgt  \
# 0           BGD      Bangladesh        M  ...             False       NaN
# 1           ARM         Armenia        M  ...             False       NaN
# 2           CAN          Canada        M  ...              True       NaN
# 3           LKA       Sri Lanka        M  ...             False       NaN
# 4           HRV         Croatia        M  ...             False       NaN
# ..          ...             ...      ...  ...               ...       ...
# 139         GBR  United Kingdom        M  ...             False       0.0
# 140         USA             USA        M  ...             False       0.0
# 141         BFA    Burkina Faso        M  ...             False       0.0
# 142         UZB      Uzbekistan        M  ...             False       0.0
# 143         ZMB          Zambia        M  ...             False       0.0
#
#     IsGrossWgtEstimated      Cifvalue  Fobvalue  PrimaryValue  \
# 0                 False  1.230924e+07       NaN  1.230924e+07
# 1                 False  1.300000e+01       NaN  1.300000e+01
# 2                 False           NaN   98223.0  9.822300e+04
# 3                 False  4.462788e+06       NaN  4.462788e+06
# 4                 False  4.050000e+02       NaN  4.050000e+02
# ..                  ...           ...       ...           ...
# 139               False  1.833766e+04       NaN  1.833766e+04
# 140               False  9.150700e+04   84781.0  9.150700e+04
# 141               False  9.694283e+03       0.0  9.694283e+03
# 142               False  1.081020e+05       NaN  1.081020e+05
# 143               False  2.776900e+01       0.0  2.776900e+01
#
#     LegacyEstimationFlag IsReported IsAggregate  Unnamed: 47
# 0                      0       True       False          NaN
# 1                      0      False       False          NaN
# 2                      6      False       False          NaN
# 3                      0      False       False          NaN
# 4                      0      False       False          NaN
# ..                   ...        ...         ...          ...
# 139                    0      False        True          NaN
# 140                    0      False        True          NaN
# 141                    0      False        True          NaN
# 142                    0      False        True          NaN
# 143                    0      False        True          NaN
#
# [144 rows x 48 columns]

# %%
df_subset = df[["RefYear","ReporterDesc", "PrimaryValue", "NetWgt"]]
pd.set_option('display.float_format', lambda x: '%d' % x)
df_subset.head(10)
# Out:
#    RefYear          ReporterDesc  PrimaryValue    NetWgt
# 0     2000            Bangladesh      12309241  69077233
# 1     2000               Armenia            13        25
# 2     2000                Canada         98223        12
# 3     2000             Sri Lanka       4462788  39444488
# 4     2000               Croatia           405       540
# 5     2000                  Cuba       3614949  26100715
# 6     2000  China, Hong Kong SAR        532223      4419
# 7     2000             Indonesia     105676329 885221217
# 8     2000                  Iran      14321451 103764498
# 9     2000                 Japan      17148890 148167000

# %%
df_china_ordenado = df_subset.sort_values(by=['PrimaryValue', 'NetWgt'], ascending=[False, False])
df_china_ordenado.head(10)
# Out:
#     RefYear   ReporterDesc  PrimaryValue     NetWgt
# 10     2000  Rep. of Korea     659815546 6296495848
# 11     2000       Malaysia     228616631 2010331024
# 7      2000      Indonesia     105676329  885221217
# 19     2000       Thailand      31258243  305979232
# 13     2000    Philippines      29463635  233837227
# 22     2000          Egypt      25453127  206558230
# 17     2000       Viet Nam      18117000        NaN
# 9      2000          Japan      17148890  148167000
# 8      2000           Iran      14321451  103764498
# 0      2000     Bangladesh      12309241   69077233

# %%
#pd.set_option('display.float_format', lambda x: '%.3f' % x) # para desactivar la notacion cientifica
df_subset_ordenado_2019 = df_subset[df_subset['RefYear'] == 2019].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2019
# Out:
#      RefYear          ReporterDesc  PrimaryValue  NetWgt
# 118     2019               Nigeria       5577882 4307192
# 83      2019                 Chile       4118535  980507
# 132     2019              Viet Nam       3598348  679000
# 81      2019                Canada        618844 4186989
# 72      2019                Angola        389216  300645
# 103     2019            Kyrgyzstan        215495  200563
# 101     2019         Rep. of Korea        193277   30626
# 136     2019            Tajikistan        167972  561820
# 97      2019  China, Hong Kong SAR        137455    5752
# 74      2019             Australia        117353   76730

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2019['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2019 = df_subset_ordenado_2019.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2019 if col != 'Importancia']
df_subset_ordenado_2019 = df_subset_ordenado_2019[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2019[['NetWgt']] = df_subset_ordenado_2019[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2019.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2019)
# Out:
#     Importancia   Año                  País  FOB[USD]  Toneladas
# 118   Numero 1   2019               Nigeria   5577882       4307
# 83    Numero 2   2019                 Chile   4118535        980
# 132   Numero 3   2019              Viet Nam   3598348        679
# 81    Numero 4   2019                Canada    618844       4186
# 72    Numero 5   2019                Angola    389216        300
# 103   Numero 6   2019            Kyrgyzstan    215495        200
# 101   Numero 7   2019         Rep. of Korea    193277         30
# 136   Numero 8   2019            Tajikistan    167972        561
# 97    Numero 9   2019  China, Hong Kong SAR    137455          5
# 74    Numero 10  2019             Australia    117353         76

# %%
df_subset_ordenado_2000 = df_subset[df_subset['RefYear'] == 2000].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2000
# Out:
#     RefYear   ReporterDesc  PrimaryValue     NetWgt
# 10     2000  Rep. of Korea     659815546 6296495848
# 11     2000       Malaysia     228616631 2010331024
# 7      2000      Indonesia     105676329  885221217
# 19     2000       Thailand      31258243  305979232
# 13     2000    Philippines      29463635  233837227
# 22     2000          Egypt      25453127  206558230
# 17     2000       Viet Nam      18117000        NaN
# 9      2000          Japan      17148890  148167000
# 8      2000           Iran      14321451  103764498
# 0      2000     Bangladesh      12309241   69077233

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2000['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2000 = df_subset_ordenado_2000.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2000 if col != 'Importancia']
df_subset_ordenado_2000 = df_subset_ordenado_2000[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2000[['NetWgt']] = df_subset_ordenado_2000[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2000.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)


# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2000)
# Out:
#    Importancia   Año           País  FOB[USD]  Toneladas
# 10   Numero 1   2000  Rep. of Korea 659815546    6296495
# 11   Numero 2   2000       Malaysia 228616631    2010331
# 7    Numero 3   2000      Indonesia 105676329     885221
# 19   Numero 4   2000       Thailand  31258243     305979
# 13   Numero 5   2000    Philippines  29463635     233837
# 22   Numero 6   2000          Egypt  25453127     206558
# 17   Numero 7   2000       Viet Nam  18117000        NaN
# 9    Numero 8   2000          Japan  17148890     148167
# 8    Numero 9   2000           Iran  14321451     103764
# 0    Numero 10  2000     Bangladesh  12309241      69077

# %%
df_subset_ordenado_2009 = df_subset[df_subset['RefYear'] == 2009].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2009
# Out:
#     RefYear     ReporterDesc  PrimaryValue   NetWgt
# 43     2009            Japan       5720646 21523000
# 49     2009  Other Asia, nes       1568405  6285000
# 45     2009    Rep. of Korea        481468  1317851
# 59     2009      Philippines        393493  1522789
# 70     2009              USA         78933    49927
# 25     2009       Bangladesh         75369    92095
# 47     2009         Malaysia         67018   304393
# 50     2009       Mozambique         62677      NaN
# 65     2009      Switzerland         62339    59949
# 63     2009         Viet Nam         49618   153987

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2009['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2009 = df_subset_ordenado_2009.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2009 if col != 'Importancia']
df_subset_ordenado_2009 = df_subset_ordenado_2009[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2009[['NetWgt']] = df_subset_ordenado_2009[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2009.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2009)
# Out:
#    Importancia   Año             País  FOB[USD]  Toneladas
# 43   Numero 1   2009            Japan   5720646      21523
# 49   Numero 2   2009  Other Asia, nes   1568405       6285
# 45   Numero 3   2009    Rep. of Korea    481468       1317
# 59   Numero 4   2009      Philippines    393493       1522
# 70   Numero 5   2009              USA     78933         49
# 25   Numero 6   2009       Bangladesh     75369         92
# 47   Numero 7   2009         Malaysia     67018        304
# 50   Numero 8   2009       Mozambique     62677        NaN
# 65   Numero 9   2009      Switzerland     62339         59
# 63   Numero 10  2009         Viet Nam     49618        153

# %%
# Vamos a redondear los números y transformarlos en números enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']

# Manejar valores no finitos (por ejemplo, NaN) reemplazándolos con 0
df_subset_ordenado_2009[columnas_a_redondear] = df_subset_ordenado_2009[columnas_a_redondear].fillna(61)

# Redondear y convertir a enteros
df_subset_ordenado_2009[columnas_a_redondear] = df_subset_ordenado_2009[columnas_a_redondear].round().astype(int)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2009)
# Out:
#    Importancia   Año             País  FOB[USD]  Toneladas
# 43   Numero 1   2009            Japan   5720646      21523
# 49   Numero 2   2009  Other Asia, nes   1568405       6285
# 45   Numero 3   2009    Rep. of Korea    481468       1318
# 59   Numero 4   2009      Philippines    393493       1523
# 70   Numero 5   2009              USA     78933         50
# 25   Numero 6   2009       Bangladesh     75369         92
# 47   Numero 7   2009         Malaysia     67018        304
# 50   Numero 8   2009       Mozambique     62677          0
# 65   Numero 9   2009      Switzerland     62339         60
# 63   Numero 10  2009         Viet Nam     49618        154

# %%
# Vamos a redondear los números y transformarlos en números enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']

# Manejar valores no finitos (por ejemplo, NaN) reemplazándolos con 0
df_subset_ordenado_2000[columnas_a_redondear] = df_subset_ordenado_2000[columnas_a_redondear].fillna(55)

# Redondear y convertir a enteros
df_subset_ordenado_2000[columnas_a_redondear] = df_subset_ordenado_2000[columnas_a_redondear].round().astype(int)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2000)
# Out:
#    Importancia   Año           País   FOB[USD]  Toneladas
# 10   Numero 1   2000  Rep. of Korea  659815546    6296496
# 11   Numero 2   2000       Malaysia  228616631    2010331
# 7    Numero 3   2000      Indonesia  105676329     885221
# 19   Numero 4   2000       Thailand   31258243     305979
# 13   Numero 5   2000    Philippines   29463635     233837
# 22   Numero 6   2000          Egypt   25453128     206558
# 17   Numero 7   2000       Viet Nam   18117000         55
# 9    Numero 8   2000          Japan   17148890     148167
# 8    Numero 9   2000           Iran   14321451     103764
# 0    Numero 10  2000     Bangladesh   12309241      69077

# %%
# Vamos a redondear los números y transformarlos en números enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']

# Manejar valores no finitos (por ejemplo, NaN) reemplazándolos con 0
df_subset_ordenado_2019[columnas_a_redondear] = df_subset_ordenado_2019[columnas_a_redondear].fillna(61)

# Redondear y convertir a enteros
df_subset_ordenado_2019[columnas_a_redondear] = df_subset_ordenado_2019[columnas_a_redondear].round().astype(int)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2019)
# Out:
#     Importancia   Año                  País  FOB[USD]  Toneladas
# 118   Numero 1   2019               Nigeria   5577883       4307
# 83    Numero 2   2019                 Chile   4118536        981
# 132   Numero 3   2019              Viet Nam   3598348        679
# 81    Numero 4   2019                Canada    618844       4187
# 72    Numero 5   2019                Angola    389217        301
# 103   Numero 6   2019            Kyrgyzstan    215495        201
# 101   Numero 7   2019         Rep. of Korea    193277         31
# 136   Numero 8   2019            Tajikistan    167972        562
# 97    Numero 9   2019  China, Hong Kong SAR    137455          6
# 74    Numero 10  2019             Australia    117353         77

# %%
df_concatenado = pd.concat([df_subset_ordenado_2000, df_subset_ordenado_2009, df_subset_ordenado_2019], ignore_index=True)
df_concatenado
# Out:
#    Importancia   Año                  País  FOB[USD]  Toneladas
# 0    Numero 1   2000         Rep. of Korea 659815546    6296495
# 1    Numero 2   2000              Malaysia 228616631    2010331
# 2    Numero 3   2000             Indonesia 105676329     885221
# 3    Numero 4   2000              Thailand  31258243     305979
# 4    Numero 5   2000           Philippines  29463635     233837
# 5    Numero 6   2000                 Egypt  25453127     206558
# 6    Numero 7   2000              Viet Nam  18117000        NaN
# 7    Numero 8   2000                 Japan  17148890     148167
# 8    Numero 9   2000                  Iran  14321451     103764
# 9    Numero 10  2000            Bangladesh  12309241      69077
# 10   Numero 1   2009                 Japan   5720646      21523
# 11   Numero 2   2009       Other Asia, nes   1568405       6285
# 12   Numero 3   2009         Rep. of Korea    481468       1317
# 13   Numero 4   2009           Philippines    393493       1522
# 14   Numero 5   2009                   USA     78933         49
# 15   Numero 6   2009            Bangladesh     75369         92
# 16   Numero 7   2009              Malaysia     67018        304
# 17   Numero 8   2009            Mozambique     62677        NaN
# 18   Numero 9   2009           Switzerland     62339         59
# 19   Numero 10  2009              Viet Nam     49618        153
# 20   Numero 1   2019               Nigeria   5577883       4307
# 21   Numero 2   2019                 Chile   4118536        981
# 22   Numero 3   2019              Viet Nam   3598348        679
# 23   Numero 4   2019                Canada    618844       4187
# 24   Numero 5   2019                Angola    389217        301
# 25   Numero 6   2019            Kyrgyzstan    215495        201
# 26   Numero 7   2019         Rep. of Korea    193277         31
# 27   Numero 8   2019            Tajikistan    167972        562
# 28   Numero 9   2019  China, Hong Kong SAR    137455          6
# 29   Numero 10  2019             Australia    117353         77

# %%
df_concatenado.to_csv('Cuadro5Maiz.csv', index=False)

# %%
df_subset_ordenado_2009
# Out:
#    Importancia   Año             País  FOB[USD]  Toneladas
# 43   Numero 1   2009            Japan   5720646      21523
# 49   Numero 2   2009  Other Asia, nes   1568405       6285
# 45   Numero 3   2009    Rep. of Korea    481468       1317
# 59   Numero 4   2009      Philippines    393493       1522
# 70   Numero 5   2009              USA     78933         49
# 25   Numero 6   2009       Bangladesh     75369         92
# 47   Numero 7   2009         Malaysia     67018        304
# 50   Numero 8   2009       Mozambique     62677        NaN
# 65   Numero 9   2009      Switzerland     62339         59
# 63   Numero 10  2009         Viet Nam     49618        153

# %%
# Visualizar el DataFrame como tabla con matplotlib 2009
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2009.values, colLabels=df_subset_ordenado_2009.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('Maiz_df_2009.png', bbox_inches='tight')

plt.show()

# %%
# Visualizar el DataFrame como tabla con matplotlib 
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2019.values, colLabels=df_subset_ordenado_2019.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('Maiz_df_2019.png', bbox_inches='tight')

plt.show()

# %%
# Visualizar el DataFrame como tabla con matplotlib 
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2000.values, colLabels=df_subset_ordenado_2000.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('Maiz_df_2000.png', bbox_inches='tight')

plt.show()

# %%
# Supongamos que deseas exportar a un archivo CSV llamado 'df_subset_ordenado.csv'
df_subset_ordenado.head(10).to_csv('df_subset_ordenado.csv', index=False)
df_subset_ordenado

# %%
print("Valores únicos de RefYear en 2019:", df_subset_ordenado_2019['RefYear'].unique())
