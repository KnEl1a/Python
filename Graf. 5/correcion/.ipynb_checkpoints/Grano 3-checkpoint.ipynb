# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# con esto leeremos el archivo tuve que hacer algo raro con ISO porque sino no agarraba

# %%
#df = pd.read_csv('C:\\Users\\Usuario\\Downloads\\Rice.csv', encoding='ISO-8859-1')
df = pd.read_csv(r"C:\Users\Usuario\Desktop\Port Folio\Pandas y Matplotlib\Proyecto I+D UNO\Graf. 5\correcion\Rice.csv", encoding='ISO-8859-1')

# %%
df
# Out:
#     TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 0          C        A     20000101     2000        52    2000             8
# 1          C        A     20000101     2000        52    2000            31
# 2          C        A     20000101     2000        52    2000            36
# 3          C        A     20000101     2000        52    2000            40
# 4          C        A     20000101     2000        52    2000            48
# ..       ...      ...          ...      ...       ...     ...           ...
# 372        C        A     20190101     2019        52    2019           858
# 373        C        A     20190101     2019        52    2019           860
# 374        C        A     20190101     2019        52    2019           882
# 375        C        A     20190101     2019        52    2019           887
# 376        C        A     20190101     2019        52    2019           894
#
#     ReporterISO ReporterDesc FlowCode  ... IsNetWgtEstimated  GrossWgt  \
# 0           ALB      Albania        M  ...             False       NaN
# 1           AZE   Azerbaijan        M  ...             False       NaN
# 2           AUS    Australia        M  ...             False       NaN
# 3           AUT      Austria        M  ...             False       NaN
# 4           BHR      Bahrain        M  ...             False       NaN
# ..          ...          ...      ...  ...               ...       ...
# 372         URY      Uruguay        M  ...             False       0.0
# 373         UZB   Uzbekistan        M  ...             False       0.0
# 374         WSM        Samoa        M  ...              True       0.0
# 375         YEM        Yemen        M  ...             False       0.0
# 376         ZMB       Zambia        M  ...             False       0.0
#
#     IsGrossWgtEstimated    Cifvalue  Fobvalue PrimaryValue  \
# 0                 False  172128.000       NaN   172128.000
# 1                 False    3638.000       NaN     3638.000
# 2                 False         NaN  36017.00    36017.000
# 3                 False   11574.000       NaN    11574.000
# 4                 False     718.000       NaN      718.000
# ..                  ...         ...       ...          ...
# 372               False    3159.280    286.95     3159.280
# 373               False     252.000       NaN      252.000
# 374               False  701269.360       NaN   701269.360
# 375               False  142562.335       NaN   142562.335
# 376               False   28832.313      0.00    28832.313
#
#     LegacyEstimationFlag IsReported IsAggregate  Unnamed: 47
# 0                      0      False       False          NaN
# 1                      0      False       False          NaN
# 2                      0      False       False          NaN
# 3                      0      False       False          NaN
# 4                      0       True       False          NaN
# ..                   ...        ...         ...          ...
# 372                    0      False        True          NaN
# 373                    0      False        True          NaN
# 374                    6      False        True          NaN
# 375                    0      False        True          NaN
# 376                    0      False        True          NaN
#
# [377 rows x 48 columns]

# %%
df_subset = df[["RefYear","ReporterDesc", "PrimaryValue", "NetWgt"]]
pd.set_option('display.float_format', lambda x: '%d' % x)
df_subset.head(10)
# Out:
#    RefYear                      ReporterDesc  PrimaryValue   NetWgt
# 0     2000                           Albania        172128   800000
# 1     2000                        Azerbaijan          3638    20060
# 2     2000                         Australia         36017    74585
# 3     2000                           Austria         11574    23500
# 4     2000                           Bahrain           718      400
# 5     2000                        Bangladesh        280382  1251000
# 6     2000                           Belgium         14989    16800
# 7     2000  Bolivia (Plurinational State of)           457      994
# 8     2000                          Botswana         46746    88570
# 9     2000                            Brazil       2811317 19938420

# %%
df_china_ordenado = df_subset.sort_values(by=['PrimaryValue', 'NetWgt'], ascending=[False, False])
df_china_ordenado.head(10)
# Out:
#      RefYear      ReporterDesc  PrimaryValue    NetWgt
# 367     2019             Egypt     159689643 161301075
# 167     2009     Rep. of Korea     159230900 163421112
# 303     2019     Rep. of Korea     127687107 157147044
# 38      2000         Indonesia     107428448 476776654
# 297     2019     Côte d'Ivoire      96397286 277371800
# 364     2019           Türkiye      96318031 243639213
# 163     2009             Japan      78283991  77436000
# 328     2019             Niger      68222245 149246280
# 21      2000              Cuba      57904731 212416542
# 333     2019  Papua New Guinea      51866960  86904732

# %%
#pd.set_option('display.float_format', lambda x: '%.3f' % x) # para desactivar la notacion cientifica
df_subset_ordenado_2019 = df_subset[df_subset['RefYear'] == 2019].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2019
# Out:
#      RefYear      ReporterDesc  PrimaryValue    NetWgt
# 367     2019             Egypt     159689643 161301075
# 303     2019     Rep. of Korea     127687107 157147044
# 297     2019     Côte d'Ivoire      96397286 277371800
# 364     2019           Türkiye      96318031 243639213
# 328     2019             Niger      68222245 149246280
# 333     2019  Papua New Guinea      51866960  86904732
# 299     2019             Japan      43864201  49349000
# 261     2019          Cameroon      34540739  95605008
# 331     2019          Pakistan      33922674  10394000
# 370     2019               USA      23597621  64510243

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2019['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2019 = df_subset_ordenado_2019.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2019 if col != 'Importancia']
df_subset_ordenado_2019 = df_subset_ordenado_2019[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2019[['NetWgt']] = df_subset_ordenado_2019[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2019.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2019)
# Out:
#     Importancia   Año              País  FOB[USD]  Toneladas
# 367   Numero 1   2019             Egypt 159689643     161301
# 303   Numero 2   2019     Rep. of Korea 127687107     157147
# 297   Numero 3   2019     Côte d'Ivoire  96397286     277371
# 364   Numero 4   2019           Türkiye  96318031     243639
# 328   Numero 5   2019             Niger  68222245     149246
# 333   Numero 6   2019  Papua New Guinea  51866960      86904
# 299   Numero 7   2019             Japan  43864201      49349
# 261   Numero 8   2019          Cameroon  34540739      95605
# 331   Numero 9   2019          Pakistan  33922674      10394
# 370   Numero 10  2019               USA  23597621      64510

# %%
df_subset_ordenado_2000 = df_subset[df_subset['RefYear'] == 2000].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2000
# Out:
#     RefYear        ReporterDesc  PrimaryValue    NetWgt
# 38     2000           Indonesia     107428448 476776654
# 21     2000                Cuba      57904731 212416542
# 41     2000       Côte d'Ivoire      37534401 181740918
# 46     2000       Rep. of Korea      37014436 132093000
# 75     2000  Russian Federation      36049831 218226831
# 43     2000               Japan      29251313  70687000
# 54     2000            Malaysia      26934580 119361000
# 13     2000            Cameroon      20624238 121002435
# 52     2000          Madagascar      17662721  93507463
# 80     2000            Viet Nam      14299000  35144260

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2000['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2000 = df_subset_ordenado_2000.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2000 if col != 'Importancia']
df_subset_ordenado_2000 = df_subset_ordenado_2000[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2000[['NetWgt']] = df_subset_ordenado_2000[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2000.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)


# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2000)
# Out:
#    Importancia   Año                País  FOB[USD]  Toneladas
# 38   Numero 1   2000           Indonesia 107428448     476776
# 21   Numero 2   2000                Cuba  57904731     212416
# 41   Numero 3   2000       Côte d'Ivoire  37534401     181740
# 46   Numero 4   2000       Rep. of Korea  37014436     132093
# 75   Numero 5   2000  Russian Federation  36049831     218226
# 43   Numero 6   2000               Japan  29251313      70687
# 54   Numero 7   2000            Malaysia  26934580     119361
# 13   Numero 8   2000            Cameroon  20624238     121002
# 52   Numero 9   2000          Madagascar  17662721      93507
# 80   Numero 10  2000            Viet Nam  14299000      35144

# %%
df_subset_ordenado_2009 = df_subset[df_subset['RefYear'] == 2009].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2009
# Out:
#      RefYear          ReporterDesc  PrimaryValue    NetWgt
# 167     2009         Rep. of Korea     159230900 163421112
# 163     2009                 Japan      78283991  77436000
# 212     2009              Viet Nam      39700499  43094179
# 214     2009          South Africa      34633599  68236891
# 156     2009  China, Hong Kong SAR      26467915  40382847
# 168     2009            Kyrgyzstan      20108900  59312700
# 161     2009         Côte d'Ivoire      18181886  38525899
# 203     2009    Russian Federation      17766619  42549200
# 157     2009             Indonesia      13697040   5167570
# 120     2009          Solomon Isds       8489235   5730811

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2009['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2009 = df_subset_ordenado_2009.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2009 if col != 'Importancia']
df_subset_ordenado_2009 = df_subset_ordenado_2009[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2009[['NetWgt']] = df_subset_ordenado_2009[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2009.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2009)
# Out:
#     Importancia   Año                  País  FOB[USD]  Toneladas
# 167   Numero 1   2009         Rep. of Korea 159230900     163421
# 163   Numero 2   2009                 Japan  78283991      77436
# 212   Numero 3   2009              Viet Nam  39700499      43094
# 214   Numero 4   2009          South Africa  34633599      68236
# 156   Numero 5   2009  China, Hong Kong SAR  26467915      40382
# 168   Numero 6   2009            Kyrgyzstan  20108900      59312
# 161   Numero 7   2009         Côte d'Ivoire  18181886      38525
# 203   Numero 8   2009    Russian Federation  17766619      42549
# 157   Numero 9   2009             Indonesia  13697040       5167
# 120   Numero 10  2009          Solomon Isds   8489235       5730

# %%
# Vamos a redondear los números y transformarlos en números enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']

# Manejar valores no finitos (por ejemplo, NaN) reemplazándolos con 0
df_subset_ordenado_2009[columnas_a_redondear] = df_subset_ordenado_2009[columnas_a_redondear].fillna(61)

# Redondear y convertir a enteros
df_subset_ordenado_2009[columnas_a_redondear] = df_subset_ordenado_2009[columnas_a_redondear].round().astype(int)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2009)
# Out:
#     Importancia   Año                  País   FOB[USD]  Toneladas
# 167   Numero 1   2009         Rep. of Korea  159230900     163421
# 163   Numero 2   2009                 Japan   78283991      77436
# 212   Numero 3   2009              Viet Nam   39700499      43094
# 214   Numero 4   2009          South Africa   34633599      68237
# 156   Numero 5   2009  China, Hong Kong SAR   26467915      40383
# 168   Numero 6   2009            Kyrgyzstan   20108900      59313
# 161   Numero 7   2009         Côte d'Ivoire   18181886      38526
# 203   Numero 8   2009    Russian Federation   17766619      42549
# 157   Numero 9   2009             Indonesia   13697040       5168
# 120   Numero 10  2009          Solomon Isds    8489236       5731

# %%
# Vamos a redondear los números y transformarlos en números enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']

# Manejar valores no finitos (por ejemplo, NaN) reemplazándolos con 0
df_subset_ordenado_2000[columnas_a_redondear] = df_subset_ordenado_2000[columnas_a_redondear].fillna(55)

# Redondear y convertir a enteros
df_subset_ordenado_2000[columnas_a_redondear] = df_subset_ordenado_2000[columnas_a_redondear].round().astype(int)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2000)
# Out:
#    Importancia   Año                País   FOB[USD]  Toneladas
# 38   Numero 1   2000           Indonesia  107428448     476777
# 21   Numero 2   2000                Cuba   57904731     212417
# 41   Numero 3   2000       Côte d'Ivoire   37534401     181741
# 46   Numero 4   2000       Rep. of Korea   37014436     132093
# 75   Numero 5   2000  Russian Federation   36049831     218227
# 43   Numero 6   2000               Japan   29251313      70687
# 54   Numero 7   2000            Malaysia   26934580     119361
# 13   Numero 8   2000            Cameroon   20624238     121002
# 52   Numero 9   2000          Madagascar   17662721      93507
# 80   Numero 10  2000            Viet Nam   14299000      35144

# %%
# Vamos a redondear los números y transformarlos en números enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']

# Manejar valores no finitos (por ejemplo, NaN) reemplazándolos con 0
df_subset_ordenado_2019[columnas_a_redondear] = df_subset_ordenado_2019[columnas_a_redondear].fillna(61)

# Redondear y convertir a enteros
df_subset_ordenado_2019[columnas_a_redondear] = df_subset_ordenado_2019[columnas_a_redondear].round().astype(int)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2019)
# Out:
#     Importancia   Año              País   FOB[USD]  Toneladas
# 367   Numero 1   2019             Egypt  159689643     161301
# 303   Numero 2   2019     Rep. of Korea  127687107     157147
# 297   Numero 3   2019     Côte d'Ivoire   96397287     277372
# 364   Numero 4   2019           Türkiye   96318031     243639
# 328   Numero 5   2019             Niger   68222246     149246
# 333   Numero 6   2019  Papua New Guinea   51866961      86905
# 299   Numero 7   2019             Japan   43864201      49349
# 261   Numero 8   2019          Cameroon   34540739      95605
# 331   Numero 9   2019          Pakistan   33922675      10394
# 370   Numero 10  2019               USA   23597621      64510

# %%
df_concatenado = pd.concat([df_subset_ordenado_2000, df_subset_ordenado_2009, df_subset_ordenado_2019], ignore_index=True)
df_concatenado
# Out:
#    Importancia   Año                  País   FOB[USD]  Toneladas
# 0    Numero 1   2000             Indonesia  107428448     476777
# 1    Numero 2   2000                  Cuba   57904731     212417
# 2    Numero 3   2000         Côte d'Ivoire   37534401     181741
# 3    Numero 4   2000         Rep. of Korea   37014436     132093
# 4    Numero 5   2000    Russian Federation   36049831     218227
# 5    Numero 6   2000                 Japan   29251313      70687
# 6    Numero 7   2000              Malaysia   26934580     119361
# 7    Numero 8   2000              Cameroon   20624238     121002
# 8    Numero 9   2000            Madagascar   17662721      93507
# 9    Numero 10  2000              Viet Nam   14299000      35144
# 10   Numero 1   2009         Rep. of Korea  159230900     163421
# 11   Numero 2   2009                 Japan   78283991      77436
# 12   Numero 3   2009              Viet Nam   39700499      43094
# 13   Numero 4   2009          South Africa   34633599      68237
# 14   Numero 5   2009  China, Hong Kong SAR   26467915      40383
# 15   Numero 6   2009            Kyrgyzstan   20108900      59313
# 16   Numero 7   2009         Côte d'Ivoire   18181886      38526
# 17   Numero 8   2009    Russian Federation   17766619      42549
# 18   Numero 9   2009             Indonesia   13697040       5168
# 19   Numero 10  2009          Solomon Isds    8489236       5731
# 20   Numero 1   2019                 Egypt  159689643     161301
# 21   Numero 2   2019         Rep. of Korea  127687107     157147
# 22   Numero 3   2019         Côte d'Ivoire   96397287     277372
# 23   Numero 4   2019               Türkiye   96318031     243639
# 24   Numero 5   2019                 Niger   68222246     149246
# 25   Numero 6   2019      Papua New Guinea   51866961      86905
# 26   Numero 7   2019                 Japan   43864201      49349
# 27   Numero 8   2019              Cameroon   34540739      95605
# 28   Numero 9   2019              Pakistan   33922675      10394
# 29   Numero 10  2019                   USA   23597621      64510

# %%
df_concatenado.to_csv('Cuadro5Rice.csv', index=False)

# %%
df_subset_ordenado_2009
# Out:
#     Importancia   Año                  País   FOB[USD]  Toneladas
# 167   Numero 1   2009         Rep. of Korea  159230900     163421
# 163   Numero 2   2009                 Japan   78283991      77436
# 212   Numero 3   2009              Viet Nam   39700499      43094
# 214   Numero 4   2009          South Africa   34633599      68237
# 156   Numero 5   2009  China, Hong Kong SAR   26467915      40383
# 168   Numero 6   2009            Kyrgyzstan   20108900      59313
# 161   Numero 7   2009         Côte d'Ivoire   18181886      38526
# 203   Numero 8   2009    Russian Federation   17766619      42549
# 157   Numero 9   2009             Indonesia   13697040       5168
# 120   Numero 10  2009          Solomon Isds    8489236       5731

# %%
# Visualizar el DataFrame como tabla con matplotlib 2009
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2009.values, colLabels=df_subset_ordenado_2009.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('Rice_df_2009.png', bbox_inches='tight')

plt.show()

# %%
# Visualizar el DataFrame como tabla con matplotlib 
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2019.values, colLabels=df_subset_ordenado_2019.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('Rice_df_2019.png', bbox_inches='tight')

plt.show()

# %%
# Visualizar el DataFrame como tabla con matplotlib 
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2000.values, colLabels=df_subset_ordenado_2000.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('Rice_df_2000.png', bbox_inches='tight')

plt.show()

# %%
# Supongamos que deseas exportar a un archivo CSV llamado 'df_subset_ordenado.csv'
df_subset_ordenado.head(10).to_csv('df_subset_ordenado.csv', index=False)
df_subset_ordenado
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Supongamos que deseas exportar a un archivo CSV llamado 'df_subset_ordenado.csv'
# ----> 2 df_subset_ordenado.head(10).to_csv('df_subset_ordenado.csv', index=False)
#       3 df_subset_ordenado
#
# NameError: name 'df_subset_ordenado' is not defined

# %%
print("Valores únicos de RefYear en 2019:", df_subset_ordenado_2019['RefYear'].unique())
