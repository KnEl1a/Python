# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# con esto leeremos el archivo tuve que hacer algo raro con ISO porque sino no agarraba

# %%
#df = pd.read_csv('C:\\Users\\Usuario\\Downloads\\Soja.csv', encoding='ISO-8859-1')
df = pd.read_csv(r"C:\Users\Usuario\Desktop\Port Folio\Pandas y Matplotlib\Proyecto I+D UNO\Graf. 5\correcion\Soja.csv", encoding='ISO-8859-1')

# %%
df
# Out:
#     TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 0          C        A     20000101     2000        52    2000            36
# 1          C        A     20000101     2000        52    2000            40
# 2          C        A     20000101     2000        52    2000            56
# 3          C        A     20000101     2000        52    2000            72
# 4          C        A     20000101     2000        52    2000           100
# ..       ...      ...          ...      ...       ...     ...           ...
# 251        C        A     20190101     2019        52    2019           826
# 252        C        A     20190101     2019        52    2019           834
# 253        C        A     20190101     2019        52    2019           842
# 254        C        A     20190101     2019        52    2019           860
# 255        C        A     20190101     2019        52    2019           887
#
#     ReporterISO             ReporterDesc FlowCode  ... IsNetWgtEstimated  \
# 0           AUS                Australia        M  ...             False
# 1           AUT                  Austria        M  ...             False
# 2           BEL                  Belgium        M  ...             False
# 3           BWA                 Botswana        M  ...             False
# 4           BGR                 Bulgaria        M  ...             False
# ..          ...                      ...      ...  ...               ...
# 251         GBR           United Kingdom        M  ...             False
# 252         TZA  United Rep. of Tanzania        M  ...             False
# 253         USA                      USA        M  ...             False
# 254         UZB               Uzbekistan        M  ...             False
# 255         YEM                    Yemen        M  ...             False
#
#      GrossWgt IsGrossWgtEstimated     Cifvalue   Fobvalue PrimaryValue  \
# 0         NaN               False          NaN    76496.0    76496.000
# 1         NaN               False     3412.000        NaN     3412.000
# 2         NaN               False   865426.000        NaN   865426.000
# 3         NaN               False       28.000        NaN       28.000
# 4         NaN               False     2883.000        NaN     2883.000
# ..        ...                 ...          ...        ...          ...
# 251       0.0               False  8362844.024        NaN  8362844.024
# 252       0.0               False     5473.000        0.0     5473.000
# 253       0.0               False  2656415.000  2488939.0  2656415.000
# 254       0.0               False    10842.000        NaN    10842.000
# 255       0.0               False     6958.938        NaN     6958.938
#
#     LegacyEstimationFlag IsReported IsAggregate  Unnamed: 47
# 0                      0      False       False          NaN
# 1                      0      False       False          NaN
# 2                      0      False       False          NaN
# 3                      0      False       False          NaN
# 4                      0      False       False          NaN
# ..                   ...        ...         ...          ...
# 251                    0      False        True          NaN
# 252                    0      False        True          NaN
# 253                    0      False        True          NaN
# 254                    0      False        True          NaN
# 255                    0      False        True          NaN
#
# [256 rows x 48 columns]

# %%
df_subset = df[["RefYear","ReporterDesc", "PrimaryValue", "NetWgt"]]
pd.set_option('display.float_format', lambda x: '%d' % x)
df_subset.head(10)
# Out:
#    RefYear ReporterDesc  PrimaryValue  NetWgt
# 0     2000    Australia         76496   85272
# 1     2000      Austria          3412    6800
# 2     2000      Belgium        865426 1500000
# 3     2000     Botswana            28      22
# 4     2000     Bulgaria          2883    2405
# 5     2000       Canada        353400 1575172
# 6     2000    Sri Lanka         44591  170505
# 7     2000        Chile           854    1000
# 8     2000      Croatia           351     367
# 9     2000       Cyprus            69      26

# %%
df_china_ordenado = df_subset.sort_values(by=['PrimaryValue', 'NetWgt'], ascending=[False, False])
df_china_ordenado.head(10)
# Out:
#      RefYear    ReporterDesc  PrimaryValue    NetWgt
# 98      2009   Rep. of Korea     132894585 177231809
# 25      2000           Japan      55784370 138537000
# 143     2009             USA      52389536  69841831
# 95      2009           Japan      44113675  51426000
# 197     2019   Rep. of Korea      39484674  43598532
# 193     2019           Japan      23599836  24490000
# 217     2019     Netherlands      11408840  16107100
# 53      2000           Egypt       9728044  43632167
# 27      2000   Rep. of Korea       8447498  43440218
# 251     2019  United Kingdom       8362844   5995284

# %%
#pd.set_option('display.float_format', lambda x: '%.3f' % x) # para desactivar la notacion cientifica
df_subset_ordenado_2019 = df_subset[df_subset['RefYear'] == 2019].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2019
# Out:
#      RefYear     ReporterDesc  PrimaryValue   NetWgt
# 197     2019    Rep. of Korea      39484674 43598532
# 193     2019            Japan      23599836 24490000
# 217     2019      Netherlands      11408840 16107100
# 251     2019   United Kingdom       8362844  5995284
# 169     2019          Denmark       7504725  9905007
# 160     2019           Canada       5051473  3727924
# 209     2019  Other Asia, nes       4810151  5064000
# 152     2019          Belgium       4723728  3110573
# 180     2019          Germany       4138236  2590544
# 149     2019        Australia       3502853  3343432

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2019['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2019 = df_subset_ordenado_2019.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2019 if col != 'Importancia']
df_subset_ordenado_2019 = df_subset_ordenado_2019[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2019[['NetWgt']] = df_subset_ordenado_2019[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2019.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2019)
# Out:
#     Importancia   Año             País  FOB[USD]  Toneladas
# 197   Numero 1   2019    Rep. of Korea  39484674      43598
# 193   Numero 2   2019            Japan  23599836      24490
# 217   Numero 3   2019      Netherlands  11408840      16107
# 251   Numero 4   2019   United Kingdom   8362844       5995
# 169   Numero 5   2019          Denmark   7504725       9905
# 160   Numero 6   2019           Canada   5051473       3727
# 209   Numero 7   2019  Other Asia, nes   4810151       5064
# 152   Numero 8   2019          Belgium   4723728       3110
# 180   Numero 9   2019          Germany   4138236       2590
# 149   Numero 10  2019        Australia   3502853       3343

# %%
df_subset_ordenado_2000 = df_subset[df_subset['RefYear'] == 2000].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2000
# Out:
#     RefYear          ReporterDesc  PrimaryValue    NetWgt
# 25     2000                 Japan      55784370 138537000
# 53     2000                 Egypt       9728044  43632167
# 27     2000         Rep. of Korea       8447498  43440218
# 2      2000               Belgium        865426   1500000
# 21     2000             Indonesia        771472   2801874
# 15     2000                France        676042   2151200
# 40     2000           Philippines        669095   1988356
# 31     2000              Malaysia        662902   1828638
# 20     2000  China, Hong Kong SAR        532961   1417916
# 55     2000                   USA        505285   2170298

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2000['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2000 = df_subset_ordenado_2000.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2000 if col != 'Importancia']
df_subset_ordenado_2000 = df_subset_ordenado_2000[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2000[['NetWgt']] = df_subset_ordenado_2000[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2000.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)


# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2000)
# Out:
#    Importancia   Año                  País  FOB[USD]  Toneladas
# 25   Numero 1   2000                 Japan  55784370     138537
# 53   Numero 2   2000                 Egypt   9728044      43632
# 27   Numero 3   2000         Rep. of Korea   8447498      43440
# 2    Numero 4   2000               Belgium    865426       1500
# 21   Numero 5   2000             Indonesia    771472       2801
# 15   Numero 6   2000                France    676042       2151
# 40   Numero 7   2000           Philippines    669095       1988
# 31   Numero 8   2000              Malaysia    662902       1828
# 20   Numero 9   2000  China, Hong Kong SAR    532961       1417
# 55   Numero 10  2000                   USA    505285       2170

# %%
df_subset_ordenado_2009 = df_subset[df_subset['RefYear'] == 2009].sort_values(by='PrimaryValue', ascending=False).head(10)
df_subset_ordenado_2009
# Out:
#      RefYear          ReporterDesc  PrimaryValue    NetWgt
# 98      2009         Rep. of Korea     132894585 177231809
# 143     2009                   USA      52389536  69841831
# 95      2009                 Japan      44113675  51426000
# 69      2009                Canada       6910308   6556348
# 63      2009               Belgium       6457666   7275651
# 106     2009       Other Asia, nes       5040662   7185952
# 84      2009               Germany       3677146   4537213
# 128     2009              Viet Nam       3446043   5719708
# 141     2009        United Kingdom       3213440   3083360
# 88      2009  China, Hong Kong SAR       2019466   2892689

# %%
# Supongamos que tienes el DataFrme df_subset_ordenado_2019

# Agregar la columna 'Importancia'
df_subset_ordenado_2009['Importancia'] = ['Numero 1 ', 'Numero 2 ','Numero 3 ','Numero 4 ', 'Numero 5 ','Numero 6 ','Numero 7 ', 'Numero 8 ','Numero 9 ','Numero 10']

# Seleccionar las primeras 10 filas y mostrar el DataFrame
df_subset_ordenado_2009 = df_subset_ordenado_2009.head(10)

# Reorganizar las columnas y mover 'Importancia' al principio del DataFrame
columnas = ['Importancia'] + [col for col in df_subset_ordenado_2009 if col != 'Importancia']
df_subset_ordenado_2009 = df_subset_ordenado_2009[columnas]

# Supongamos que tienes un DataFrame df y deseas dividir todas las columnas por 10
df_subset_ordenado_2009[['NetWgt']] = df_subset_ordenado_2009[['NetWgt']] / 1000 #como esta en kg

df_subset_ordenado_2009.rename(columns={'RefYear': 'Año', 'ReporterDesc': 'País', 'PrimaryValue':'FOB[USD]', 'NetWgt':'Toneladas'}, inplace=True)

# Mostrar el DataFrame actualizado
print(df_subset_ordenado_2009)
# Out:
#     Importancia   Año                  País  FOB[USD]  Toneladas
# 98    Numero 1   2009         Rep. of Korea 132894585     177231
# 143   Numero 2   2009                   USA  52389536      69841
# 95    Numero 3   2009                 Japan  44113675      51426
# 69    Numero 4   2009                Canada   6910308       6556
# 63    Numero 5   2009               Belgium   6457666       7275
# 106   Numero 6   2009       Other Asia, nes   5040662       7185
# 84    Numero 7   2009               Germany   3677146       4537
# 128   Numero 8   2009              Viet Nam   3446043       5719
# 141   Numero 9   2009        United Kingdom   3213440       3083
# 88    Numero 10  2009  China, Hong Kong SAR   2019466       2892

# %%
#vamos a redondear los numeros y transformarlos en numeros enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']
df_subset_ordenado_2009[columnas_a_redondear] = df_subset_ordenado_2009[columnas_a_redondear].round().astype(int)
df_subset_ordenado_2009
# Out:
#     Importancia   Año                  País   FOB[USD]  Toneladas
# 98    Numero 1   2009         Rep. of Korea  132894585     177232
# 143   Numero 2   2009                   USA   52389536      69842
# 95    Numero 3   2009                 Japan   44113675      51426
# 69    Numero 4   2009                Canada    6910308       6556
# 63    Numero 5   2009               Belgium    6457666       7276
# 106   Numero 6   2009       Other Asia, nes    5040662       7186
# 84    Numero 7   2009               Germany    3677147       4537
# 128   Numero 8   2009              Viet Nam    3446043       5720
# 141   Numero 9   2009        United Kingdom    3213440       3083
# 88    Numero 10  2009  China, Hong Kong SAR    2019466       2893

# %%
#vamos a redondear los numeros y transformarlos en numeros enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']
df_subset_ordenado_2000[columnas_a_redondear] = df_subset_ordenado_2000[columnas_a_redondear].round().astype(int)
df_subset_ordenado_2000
# Out:
#    Importancia   Año                  País  FOB[USD]  Toneladas
# 25   Numero 1   2000                 Japan  55784370     138537
# 53   Numero 2   2000                 Egypt   9728045      43632
# 27   Numero 3   2000         Rep. of Korea   8447498      43440
# 2    Numero 4   2000               Belgium    865426       1500
# 21   Numero 5   2000             Indonesia    771472       2802
# 15   Numero 6   2000                France    676042       2151
# 40   Numero 7   2000           Philippines    669095       1988
# 31   Numero 8   2000              Malaysia    662902       1829
# 20   Numero 9   2000  China, Hong Kong SAR    532961       1418
# 55   Numero 10  2000                   USA    505285       2170

# %%
#vamos a redondear los numeros y transformarlos en numeros enteros
columnas_a_redondear = ['FOB[USD]', 'Toneladas']
df_subset_ordenado_2019[columnas_a_redondear] = df_subset_ordenado_2019[columnas_a_redondear].round().astype(int)
df_subset_ordenado_2019
# Out:
#     Importancia   Año             País  FOB[USD]  Toneladas
# 197   Numero 1   2019    Rep. of Korea  39484674      43599
# 193   Numero 2   2019            Japan  23599836      24490
# 217   Numero 3   2019      Netherlands  11408840      16107
# 251   Numero 4   2019   United Kingdom   8362844       5995
# 169   Numero 5   2019          Denmark   7504725       9905
# 160   Numero 6   2019           Canada   5051473       3728
# 209   Numero 7   2019  Other Asia, nes   4810152       5064
# 152   Numero 8   2019          Belgium   4723729       3111
# 180   Numero 9   2019          Germany   4138237       2591
# 149   Numero 10  2019        Australia   3502854       3343

# %%
df_subset_ordenado_2019
# Out:
#     Importancia   Año             País  FOB[USD]  Toneladas
# 197   Numero 1   2019    Rep. of Korea  39484674      43599
# 193   Numero 2   2019            Japan  23599836      24490
# 217   Numero 3   2019      Netherlands  11408840      16107
# 251   Numero 4   2019   United Kingdom   8362844       5995
# 169   Numero 5   2019          Denmark   7504725       9905
# 160   Numero 6   2019           Canada   5051473       3728
# 209   Numero 7   2019  Other Asia, nes   4810152       5064
# 152   Numero 8   2019          Belgium   4723729       3111
# 180   Numero 9   2019          Germany   4138237       2591
# 149   Numero 10  2019        Australia   3502854       3343

# %%
df_concatenado = pd.concat([df_subset_ordenado_2000, df_subset_ordenado_2009, df_subset_ordenado_2019], ignore_index=True)
df_concatenado
# Out:
#    Importancia   Año                  País   FOB[USD]  Toneladas
# 0    Numero 1   2000                 Japan   55784370     138537
# 1    Numero 2   2000                 Egypt    9728045      43632
# 2    Numero 3   2000         Rep. of Korea    8447498      43440
# 3    Numero 4   2000               Belgium     865426       1500
# 4    Numero 5   2000             Indonesia     771472       2802
# 5    Numero 6   2000                France     676042       2151
# 6    Numero 7   2000           Philippines     669095       1988
# 7    Numero 8   2000              Malaysia     662902       1829
# 8    Numero 9   2000  China, Hong Kong SAR     532961       1418
# 9    Numero 10  2000                   USA     505285       2170
# 10   Numero 1   2009         Rep. of Korea  132894585     177232
# 11   Numero 2   2009                   USA   52389536      69842
# 12   Numero 3   2009                 Japan   44113675      51426
# 13   Numero 4   2009                Canada    6910308       6556
# 14   Numero 5   2009               Belgium    6457666       7276
# 15   Numero 6   2009       Other Asia, nes    5040662       7186
# 16   Numero 7   2009               Germany    3677147       4537
# 17   Numero 8   2009              Viet Nam    3446043       5720
# 18   Numero 9   2009        United Kingdom    3213440       3083
# 19   Numero 10  2009  China, Hong Kong SAR    2019466       2893
# 20   Numero 1   2019         Rep. of Korea   39484674      43599
# 21   Numero 2   2019                 Japan   23599836      24490
# 22   Numero 3   2019           Netherlands   11408840      16107
# 23   Numero 4   2019        United Kingdom    8362844       5995
# 24   Numero 5   2019               Denmark    7504725       9905
# 25   Numero 6   2019                Canada    5051473       3728
# 26   Numero 7   2019       Other Asia, nes    4810152       5064
# 27   Numero 8   2019               Belgium    4723729       3111
# 28   Numero 9   2019               Germany    4138237       2591
# 29   Numero 10  2019             Australia    3502854       3343

# %%
path = r'C:\Users\Usuario\Desktop\Port Folio\Pandas y Matplotlib\Proyecto I+D UNO\Graf. 5\correcion\\'
name_file = 'Cuadro5Soja.csv'
name_file_xl = 'Cuadro5Soja.xlsx'
df_concatenado.to_csv(path + name_file, index=False)
df_concatenado.to_excel(path + name_file_xl, index=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1153, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1152 try:
# -> 1153     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1154     if engine == "auto":
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:272, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     271 def __call__(self, *args, **kwds) -> T:
# --> 272     return self.__func__(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:132, in _get_single_key(pat, silent)
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#
# OptionError: No such keys(s): 'io.excel.csv.writer'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 4
#       2 name_file = 'Cuadro5Soja.csv'
#       3 df_concatenado.to_csv(path + name_file, index=False)
# ----> 4 df_concatenado.to_excel(path + name_file, index=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353     engine_kwargs=engine_kwargs,
#    2354 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\excel.py:946, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     942     need_save = False
#     943 else:
#     944     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     945     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 946     writer = ExcelWriter(  # type: ignore[abstract]
#     947         writer,
#     948         engine=engine,
#     949         storage_options=storage_options,
#     950         engine_kwargs=engine_kwargs,
#     951     )
#     952     need_save = True
#     954 try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1157, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1155             engine = get_default_engine(ext, mode="writer")
#    1156     except KeyError as err:
# -> 1157         raise ValueError(f"No engine for filetype: '{ext}'") from err
#    1159 # for mypy
#    1160 assert engine is not None
#
# ValueError: No engine for filetype: 'csv'

# %%
df_subset_ordenado_2009
# Out:
#     Importancia   Año                  País   FOB[USD]  Toneladas
# 98    Numero 1   2009         Rep. of Korea  132894585     177232
# 143   Numero 2   2009                   USA   52389536      69842
# 95    Numero 3   2009                 Japan   44113675      51426
# 69    Numero 4   2009                Canada    6910308       6556
# 63    Numero 5   2009               Belgium    6457666       7276
# 106   Numero 6   2009       Other Asia, nes    5040662       7186
# 84    Numero 7   2009               Germany    3677147       4537
# 128   Numero 8   2009              Viet Nam    3446043       5720
# 141   Numero 9   2009        United Kingdom    3213440       3083
# 88    Numero 10  2009  China, Hong Kong SAR    2019466       2893

# %%
# Visualizar el DataFrame como tabla con matplotlib 2009
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2009.values, colLabels=df_subset_ordenado_2009.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('soja_df_2009.png', bbox_inches='tight')

plt.show()

# %%
# Visualizar el DataFrame como tabla con matplotlib 
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2019.values, colLabels=df_subset_ordenado_2019.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('soja_df_2019.png', bbox_inches='tight')

plt.show()

# %%
# Visualizar el DataFrame como tabla con matplotlib 
fig, ax = plt.subplots(figsize=(14,7))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df_subset_ordenado_2000.values, colLabels=df_subset_ordenado_2000.columns, cellLoc='center', loc='center')

# Guardar la visualización como una imagen PNG
plt.savefig('soja_df_2000.png', bbox_inches='tight')

plt.show()

# %%
# Supongamos que deseas exportar a un archivo CSV llamado 'df_subset_ordenado.csv'
df_subset_ordenado.head(10).to_csv('df_subset_ordenado.csv', index=False)
df_subset_ordenado
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Supongamos que deseas exportar a un archivo CSV llamado 'df_subset_ordenado.csv'
# ----> 2 df_subset_ordenado.head(10).to_csv('df_subset_ordenado.csv', index=False)
#       3 df_subset_ordenado
#
# NameError: name 'df_subset_ordenado' is not defined

# %%
print("Valores únicos de RefYear en 2019:", df_subset_ordenado_2019['RefYear'].unique())
